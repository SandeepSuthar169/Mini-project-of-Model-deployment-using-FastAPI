# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
from sklearn.preprocessing import  (StandardScaler,
                                    MinMaxScaler,
                                    OneHotEncoder,
                                    LabelEncoder,
                                    )
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import (Pipeline,
                              make_pipeline
                              )
from sklearn.metrics import   (accuracy_score,
                               precision_score,
                               r2_score,
                               confusion_matrix)

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv(r'C:\Users\Sande\Desktop\model\notebook\heart.csv')
df.head(4)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1

# %%
df['ChestPainType'] = df['ChestPainType'].replace({
    "ASY": 4,
    "NAP":3,
    "ATA":2,
    "TA":1
    })
df['ChestPainType'] = df['ChestPainType'].astype(int)
# Out:
# C:\Users\Sande\AppData\Local\Temp\ipykernel_12964\2708649609.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ChestPainType'] = df['ChestPainType'].replace({

# %%
df['RestingECG'] = df['RestingECG'].replace({
    "Normal": 1,
    "ST": 2,
    "LVH":3
    })
df['RestingECG'] = df['RestingECG'].astype(int)
# Out:
# C:\Users\Sande\AppData\Local\Temp\ipykernel_12964\633966466.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['RestingECG'] = df['RestingECG'].replace({

# %%
df['ST_Slope'] = df['ST_Slope'].replace({
    "Flat": 1,
    "Up": 2,
    "Down": 3
    })
df['ST_Slope'] = df['ST_Slope'].astype(int)
# Out:
# C:\Users\Sande\AppData\Local\Temp\ipykernel_12964\688304395.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ST_Slope'] = df['ST_Slope'].replace({

# %%
process = ColumnTransformer(transformers=[
    ('one', OneHotEncoder(), ['ExerciseAngina', 'Sex']),
    ('std', StandardScaler(), ['MaxHR', 'Age', 'RestingBP', 'Cholesterol'])
],
    remainder='passthrough'
)

# %%
Pipeline = Pipeline(steps=[
    ('proprocess', process),
    ('classi', RandomForestClassifier())
])

# %%
train_data, test_data = train_test_split(df, random_state=42, test_size=0.21)

# %%
X_train = train_data.drop(columns=['HeartDisease'])
y_train = train_data['HeartDisease']

X_test = test_data.drop(columns=['HeartDisease'])
y_test = test_data['HeartDisease']

# %%
Pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('proprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one', OneHotEncoder(),
#                                                   ['ExerciseAngina', 'Sex']),
#                                                  ('std', StandardScaler(),
#                                                   ['MaxHR', 'Age', 'RestingBP',
#                                                    'Cholesterol'])])),
#                 ('classi', RandomForestClassifier())])

# %%
y_pred = Pipeline.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
print(acc)
# Out:
# 0.8911917098445595

# %%
pickle_model_path = 'model.pkl'
with open(pickle_model_path, 'wb') as file:
    pickle.dump(Pipeline, file)
